# %%
import GEOparse
import pandas as pd
import numpy as np

# %%
import pylab as pl
import seaborn as sns
pl.rcParams['figure.figsize'] = (14, 10)
pl.rcParams['ytick.labelsize'] = 12
pl.rcParams['xtick.labelsize'] = 11
pl.rcParams['axes.labelsize'] = 23
pl.rcParams['legend.fontsize'] = 20
sns.set_style('ticks')
c1, c2, c3, c4 = sns.color_palette("Set1", 4)

# %%
gse = GEOparse.get_GEO("GSE20295");
# Out:
# 04-Jun-2019 12:35:16 DEBUG utils - Directory ./ already exists. Skipping.
# 04-Jun-2019 12:35:16 INFO GEOparse - File already exist: using local version.
# 04-Jun-2019 12:35:16 INFO GEOparse - Parsing ./GSE20295_family.soft.gz:
# 04-Jun-2019 12:35:16 DEBUG GEOparse - DATABASE: GeoMiame
# 04-Jun-2019 12:35:16 DEBUG GEOparse - SERIES: GSE20295
# 04-Jun-2019 12:35:16 DEBUG GEOparse - PLATFORM: GPL96
# 04-Jun-2019 12:35:17 DEBUG GEOparse - SAMPLE: GSM506037
# 04-Jun-2019 12:35:17 DEBUG GEOparse - SAMPLE: GSM506039
# 04-Jun-2019 12:35:17 DEBUG GEOparse - SAMPLE: GSM506040
# 04-Jun-2019 12:35:17 DEBUG GEOparse - SAMPLE: GSM506041
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506042
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506043
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506044
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506045
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506046
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506047
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506048
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506050
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506051
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506052
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506053
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506054
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506055
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506056
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506057
# 04-Jun-2019 12:35:18 DEBUG GEOparse - SAMPLE: GSM506059
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506060
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506061
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506062
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506063
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506064
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506065
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506066
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506067
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM506068
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508594
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508608
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508609
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508610
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508611
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508627
# 04-Jun-2019 12:35:19 DEBUG GEOparse - SAMPLE: GSM508628
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508629
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508661
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508683
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508684
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508686
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508687
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508688
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508689
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508690
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508691
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508692
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508693
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508695
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508696
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508697
# 04-Jun-2019 12:35:20 DEBUG GEOparse - SAMPLE: GSM508699
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508700
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508701
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508702
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508703
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508704
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508705
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508706
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508708
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508710
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508711
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508712
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508713
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508714
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508715
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508716
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508717
# 04-Jun-2019 12:35:21 DEBUG GEOparse - SAMPLE: GSM508718
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508720
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508721
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508722
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508723
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508724
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508725
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508726
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508728
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508729
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508730
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508731
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508732
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508733
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508734
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM508735
# 04-Jun-2019 12:35:22 DEBUG GEOparse - SAMPLE: GSM521253
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606619
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606620
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606621
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606622
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606623
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606624
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606625
# 04-Jun-2019 12:35:23 DEBUG GEOparse - SAMPLE: GSM606626

# %%
gse.metadata['title']
# Out:
# ["Transcriptional analysis of multiple brain regions in Parkinson's disease"]

# %%
gse.metadata['summary']
# Out:
# ["Transcriptional analysis of multiple brain regions in Parkinson's disease supports the involvement of specific protein processing, energy metabolism, and signaling pathways, and suggests novel disease mechanisms.",
#  '',
#  'This SuperSeries is composed of the SubSeries listed below.']

# %%
gse.metadata['sample_id']
# Out:
# ['GSM506037',
#  'GSM506039',
#  'GSM506040',
#  'GSM506041',
#  'GSM506042',
#  'GSM506043',
#  'GSM506044',
#  'GSM506045',
#  'GSM506046',
#  'GSM506047',
#  'GSM506048',
#  'GSM506050',
#  'GSM506051',
#  'GSM506052',
#  'GSM506053',
#  'GSM506054',
#  'GSM506055',
#  'GSM506056',
#  'GSM506057',
#  'GSM506059',
#  'GSM506060',
#  'GSM506061',
#  'GSM506062',
#  'GSM506063',
#  'GSM506064',
#  'GSM506065',
#  'GSM506066',
#  'GSM506067',
#  'GSM506068',
#  'GSM508594',
#  'GSM508608',
#  'GSM508609',
#  'GSM508610',
#  'GSM508611',
#  'GSM508627',
#  'GSM508628',
#  'GSM508629',
#  'GSM508661',
#  'GSM508683',
#  'GSM508684',
#  'GSM508686',
#  'GSM508687',
#  'GSM508688',
#  'GSM508689',
#  'GSM508690',
#  'GSM508691',
#  'GSM508692',
#  'GSM508693',
#  'GSM508695',
#  'GSM508696',
#  'GSM508697',
#  'GSM508699',
#  'GSM508700',
#  'GSM508701',
#  'GSM508702',
#  'GSM508703',
#  'GSM508704',
#  'GSM508705',
#  'GSM508706',
#  'GSM508708',
#  'GSM508710',
#  'GSM508711',
#  'GSM508712',
#  'GSM508713',
#  'GSM508714',
#  'GSM508715',
#  'GSM508716',
#  'GSM508717',
#  'GSM508718',
#  'GSM508720',
#  'GSM508721',
#  'GSM508722',
#  'GSM508723',
#  'GSM508724',
#  'GSM508725',
#  'GSM508726',
#  'GSM508728',
#  'GSM508729',
#  'GSM508730',
#  'GSM508731',
#  'GSM508732',
#  'GSM508733',
#  'GSM508734',
#  'GSM508735',
#  'GSM521253',
#  'GSM606619',
#  'GSM606620',
#  'GSM606621',
#  'GSM606622',
#  'GSM606623',
#  'GSM606624',
#  'GSM606625',
#  'GSM606626']

# %%
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print ("Table data:",)
    print (gsm.table.head())
    break
# Out:
# Name:  GSM506037
# Metadata:
#  - title : 1206 BA9 Cm
#  - geo_accession : GSM506037
#  - status : Public on Feb 04 2010
#  - submission_date : Feb 02 2010
#  - last_update_date : Mar 10 2010
#  - type : RNA
#  - channel_count : 1
#  - source_name_ch1 : Postmortem brain prefrontal cortex
#  - organism_ch1 : Homo sapiens
#  - taxid_ch1 : 9606
#  - characteristics_ch1 : disease state: control, gender: male, age: 57, brain region: Prefrontal cortex area 9
#  - molecule_ch1 : total RNA
#  - extract_protocol_ch1 : RNeasy (Qiagen)
#  - label_ch1 : biotin
#  - label_protocol_ch1 : Standard Two-Cycle cRNA IVT method (Affymetrix Expression Analysis Technical Manual 701021 rev 5)
#  - hyb_protocol : Standard method (Affymetrix Expression Analysis Technical Manual 701021 rev 5)
#  - scan_protocol : Standard method (Affymetrix Expression Analysis Technical Manual 701021 rev 5)
#  - description : One of 29 samples in this series
#  - data_processing : To obtain the most stringent normalization possible on the dataset, we implemented the Robust Multichip Analysis method [Irizarry et al., [2003]] for the complete set of chips derived from each brain area. These robust multi-array analysis (RMA)-normalized data were imported into GeneSpring 7.0 (Silicon Genetics) for significance analysis and pattern analysis (clustering). To obtain the most accurate cross-gene error model for subsequent statistical analyses, the individual transcript data were further normalized within each respective brain area to the mean intensity measurements of the control subject samples for that brain area and transcript.
#  - platform_id : GPL96
#  - contact_name : Frank,A,Middleton
#  - contact_email : middletf@upstate.edu
#  - contact_phone : 315-464-7721
#  - contact_department : Neuroscience and Physiology
#  - contact_institute : SUNY Upstate Medical Univ
#  - contact_address : 750 East Adams St
#  - contact_city : Syracuse
#  - contact_state : NY
#  - contact_zip/postal_code : 13210
#  - contact_country : USA
#  - supplementary_file : ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506nnn/GSM506037/suppl/GSM506037_1206_BA9_Cm.CEL.gz, ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506nnn/GSM506037/suppl/GSM506037_1206_BA9_Cm.mas5.CHP.gz
#  - series_id : GSE20168, GSE20295
#  - data_row_count : 22283
# Table data:
#            ID_REF     VALUE
# 0  AFFX-BioB-5_at  7.462995
# 1  AFFX-BioB-M_at  8.282074
# 2  AFFX-BioB-3_at  7.121292
# 3  AFFX-BioC-5_at  8.762952
# 4  AFFX-BioC-3_at  8.199382

# %%
pivoted_samples = gse.pivot_samples('VALUE')
# Out:
# /home/ranap/anaconda3/envs/BioSandbox/lib/python3.6/site-packages/GEOparse/GEOTypes.py:794: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   ndf = concat(data).pivot(index=index, values=values, columns="name")

# %%
pivoted_samples.head()
# Out:
# name       GSM506037  GSM506039  GSM506040  GSM506041  GSM506042  GSM506043  \
# ID_REF
# 1007_s_at  10.912450  11.570700  11.272380  10.831860  10.734560  11.166910
# 1053_at     6.219040   6.188796   6.147970   6.230091   6.150496   6.298738
# 117_at      7.197164   7.222397   7.348107   7.531583   7.617554   7.184102
# 121_at      9.234383   9.306890   9.523680   9.277714   9.338842   9.409475
# 1255_g_at   5.608969   5.531456   5.627622   5.626012   5.566833   5.611449
#
# name       GSM506044  GSM506045  GSM506046  GSM506047    ...      GSM508735  \
# ID_REF                                                   ...
# 1007_s_at  11.662920  11.607970  11.348840  11.629370    ...      12.018050
# 1053_at     6.237519   6.066697   6.094995   6.120762    ...       5.928751
# 117_at     10.566390   7.271068   7.163742   7.175694    ...       7.050250
# 121_at      9.177028   9.250935   9.330317   9.245938    ...       9.236322
# 1255_g_at   5.627075   5.479886   5.548875   5.510530    ...       5.643215
#
# name       GSM521253  GSM606619  GSM606620  GSM606621  GSM606622  GSM606623  \
# ID_REF
# 1007_s_at  11.639670   2248.440   2143.520  2171.8400   3775.640  1423.3000
# 1053_at     5.654763    277.794     86.143    70.2282    178.786    84.1708
# 117_at      7.119349    152.827    148.490   129.9350    184.308   423.7160
# 121_at      9.445329    759.988    935.717  1379.1900   1253.160   755.0720
# 1255_g_at   5.623552    547.780    477.638   704.8500    208.416   635.7510
#
# name       GSM606624  GSM606625  GSM606626
# ID_REF
# 1007_s_at   3190.330  2468.7700  3616.5900
# 1053_at      139.303    37.7073    90.8564
# 117_at       189.210   176.2590   155.5370
# 121_at       800.507  1356.1200  1649.2500
# 1255_g_at    306.296   283.0780   228.9750
#
# [5 rows x 93 columns]

# %%
pivoted_samples_average = pivoted_samples.median(axis=1)
print("Number of probes before filtering: ", len(pivoted_samples_average))
# Out:
# Number of probes before filtering:  22283

# %%
expression_threshold = pivoted_samples_average.quantile(0.25)

# %%
expressed_probes = pivoted_samples_average[pivoted_samples_average >= expression_threshold].index.tolist()
print("Number of probes above threshold: ", len(expressed_probes))
# Out:
# Number of probes above threshold:  16712

# %%
samples = gse.pivot_samples("VALUE").ix[expressed_probes]
# Out:
# /home/ranap/anaconda3/envs/BioSandbox/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
samples.head()
# Out:
# name       GSM506037  GSM506039  GSM506040  GSM506041  GSM506042  GSM506043  \
# ID_REF
# 1007_s_at  10.912450  11.570700  11.272380  10.831860  10.734560  11.166910
# 117_at      7.197164   7.222397   7.348107   7.531583   7.617554   7.184102
# 121_at      9.234383   9.306890   9.523680   9.277714   9.338842   9.409475
# 1294_at     7.596421   8.054777   8.008759   8.002590   8.317605   7.840319
# 1316_at     7.095303   6.990960   7.011986   6.989883   6.670824   6.839299
#
# name       GSM506044  GSM506045  GSM506046  GSM506047    ...      GSM508735  \
# ID_REF                                                   ...
# 1007_s_at  11.662920  11.607970  11.348840  11.629370    ...      12.018050
# 117_at     10.566390   7.271068   7.163742   7.175694    ...       7.050250
# 121_at      9.177028   9.250935   9.330317   9.245938    ...       9.236322
# 1294_at     7.795486   7.841074   7.938321   7.758112    ...       8.026506
# 1316_at     6.961096   7.334647   7.314097   6.946249    ...       6.232637
#
# name       GSM521253  GSM606619  GSM606620  GSM606621  GSM606622  GSM606623  \
# ID_REF
# 1007_s_at  11.639670   2248.440   2143.520   2171.840   3775.640   1423.300
# 117_at      7.119349    152.827    148.490    129.935    184.308    423.716
# 121_at      9.445329    759.988    935.717   1379.190   1253.160    755.072
# 1294_at     7.977628    264.273    237.344    246.465    252.270    244.816
# 1316_at     6.335979    146.966    239.745    299.628    231.731    208.184
#
# name       GSM606624  GSM606625  GSM606626
# ID_REF
# 1007_s_at   3190.330   2468.770   3616.590
# 117_at       189.210    176.259    155.537
# 121_at       800.507   1356.120   1649.250
# 1294_at      268.332    174.181    386.530
# 1316_at      145.039    159.895    205.464
#
# [5 rows x 93 columns]

# %%
gse.phenotype_data.T
# Out:
#                                                                              GSM506037  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            control
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                      male
# characteristics_ch1.2.age                                                           57
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506037
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      1206 BA9 Cm
# type                                                                               RNA
#
#                                                                              GSM506039  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                      male
# characteristics_ch1.2.age                                                           73
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506039
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      1364 BA9 Pm
# type                                                                               RNA
#
#                                                                              GSM506040  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           80
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506040
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      1401 BA9 Pf
# type                                                                               RNA
#
#                                                                              GSM506041  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           78
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506041
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      1516 BA9 Pf
# type                                                                               RNA
#
#                                                                              GSM506042  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           84
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506042
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      1647 BA9 Pf
# type                                                                               RNA
#
#                                                                              GSM506043  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           70
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506043
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      2515 BA9 Pf
# type                                                                               RNA
#
#                                                                              GSM506044  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           82
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506044
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      2525 BA9 Pf
# type                                                                               RNA
#
#                                                                              GSM506045  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                      male
# characteristics_ch1.2.age                                                           70
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506045
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      2685 BA9 Pm
# type                                                                               RNA
#
#                                                                              GSM506046  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                Parkinson's disease
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                      male
# characteristics_ch1.2.age                                                           80
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506046
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      2729 BA9 Pm
# type                                                                               RNA
#
#                                                                              GSM506047  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            control
# characteristics_ch1.1.age                                                          NaN
# characteristics_ch1.1.gender                                                    female
# characteristics_ch1.2.age                                                           94
# characteristics_ch1.2.gender                                                       NaN
# characteristics_ch1.3.brain region                            Prefrontal cortex area 9
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                           One of 29 samples in this series
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM506047
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Mar 10 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20168,GSE20295
# source_name_ch1                                     Postmortem brain prefrontal cortex
# status                                                           Public on Feb 04 2010
# submission_date                                                            Feb 02 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM506n...
# taxid_ch1                                                                         9606
# title                                                                      2829 BA9 Cf
# type                                                                               RNA
#
#                                                            ...                          \
# channel_count                                              ...
# characteristics_ch1.0.disease state                        ...
# characteristics_ch1.1.age                                  ...
# characteristics_ch1.1.gender                               ...
# characteristics_ch1.2.age                                  ...
# characteristics_ch1.2.gender                               ...
# characteristics_ch1.3.brain region                         ...
# contact_address                                            ...
# contact_city                                               ...
# contact_country                                            ...
# contact_department                                         ...
# contact_email                                              ...
# contact_institute                                          ...
# contact_name                                               ...
# contact_phone                                              ...
# contact_state                                              ...
# contact_zip/postal_code                                    ...
# data_processing                                            ...
# data_row_count                                             ...
# description                                                ...
# extract_protocol_ch1                                       ...
# geo_accession                                              ...
# hyb_protocol                                               ...
# label_ch1                                                  ...
# label_protocol_ch1                                         ...
# last_update_date                                           ...
# molecule_ch1                                               ...
# organism_ch1                                               ...
# platform_id                                                ...
# scan_protocol                                              ...
# series_id                                                  ...
# source_name_ch1                                            ...
# status                                                     ...
# submission_date                                            ...
# supplementary_file                                         ...
# taxid_ch1                                                  ...
# title                                                      ...
# type                                                       ...
#
#                                                                              GSM508735  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           55
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region        Whole substantia nigra from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM508735
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20292,GSE20295
# source_name_ch1                                Postmortem brain whole substantia nigra
# status                                                           Public on Mar 12 2010
# submission_date                                                            Feb 11 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM508n...
# taxid_ch1                                                                         9606
# title                                                                        T98 SN Cm
# type                                                                               RNA
#
#                                                                              GSM521253  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           59
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region        Whole substantia nigra from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      To obtain the most stringent normalization pos...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM521253
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20292,GSE20295
# source_name_ch1                                Postmortem brain whole substantia nigra
# status                                                           Public on Mar 12 2010
# submission_date                                                            Mar 11 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM521n...
# taxid_ch1                                                                         9606
# title                                                                       3576 SN Cm
# type                                                                               RNA
#
#                                                                              GSM606619  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           41
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region                       Putamen from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606619
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# ...
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606622
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20291,GSE20295
# source_name_ch1                                               Postmortem brain putamen
# status                                                           Public on Oct 13 2010
# submission_date                                                            Oct 08 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM606n...
# taxid_ch1                                                                         9606
# title                                                                       3747 PT Cm
# type                                                                               RNA
#
#                                                                              GSM606623  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           68
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region                       Putamen from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606623
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20291,GSE20295
# source_name_ch1                                               Postmortem brain putamen
# status                                                           Public on Oct 13 2010
# submission_date                                                            Oct 08 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM606n...
# taxid_ch1                                                                         9606
# title                                                                       5386 PT Cm
# type                                                                               RNA
#
#                                                                              GSM606624  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           41
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region        Whole substantia nigra from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606624
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20292,GSE20295
# source_name_ch1                                Postmortem brain whole substantia nigra
# status                                                           Public on Oct 13 2010
# submission_date                                                            Oct 08 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM606n...
# taxid_ch1                                                                         9606
# title                                                                       1134 SN Cm
# type                                                                               RNA
#
#                                                                              GSM606625  \
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           42
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region        Whole substantia nigra from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606625
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20292,GSE20295
# source_name_ch1                                Postmortem brain whole substantia nigra
# status                                                           Public on Oct 13 2010
# submission_date                                                            Oct 08 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM606n...
# taxid_ch1                                                                         9606
# title                                                                       1266 SN Cm
# type                                                                               RNA
#
#                                                                              GSM606626
# channel_count                                                                        1
# characteristics_ch1.0.disease state                                            Control
# characteristics_ch1.1.age                                                           53
# characteristics_ch1.1.gender                                                       NaN
# characteristics_ch1.2.age                                                          NaN
# characteristics_ch1.2.gender                                                      male
# characteristics_ch1.3.brain region        Whole substantia nigra from postmortem brain
# contact_address                                                      750 East Adams St
# contact_city                                                                  Syracuse
# contact_country                                                                    USA
# contact_department                                         Neuroscience and Physiology
# contact_email                                                     middletf@upstate.edu
# contact_institute                                            SUNY Upstate Medical Univ
# contact_name                                                         Frank,A,Middleton
# contact_phone                                                             315-464-7721
# contact_state                                                                       NY
# contact_zip/postal_code                                                          13210
# data_processing                      MAS5.0 normalized in Gene Expression Console 1...
# data_row_count                                                                   22283
# description                                                                        NaN
# extract_protocol_ch1                                                   RNeasy (Qiagen)
# geo_accession                                                                GSM606626
# hyb_protocol                         Standard method (Affymetrix Expression Analysi...
# label_ch1                                                                       biotin
# label_protocol_ch1                   Standard Two-Cycle cRNA IVT method (Affymetrix...
# last_update_date                                                           Oct 13 2010
# molecule_ch1                                                                 total RNA
# organism_ch1                                                              Homo sapiens
# platform_id                                                                      GPL96
# scan_protocol                        Standard method (Affymetrix Expression Analysi...
# series_id                                                            GSE20292,GSE20295
# source_name_ch1                                Postmortem brain whole substantia nigra
# status                                                           Public on Oct 13 2010
# submission_date                                                            Oct 08 2010
# supplementary_file                   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM606n...
# taxid_ch1                                                                         9606
# title                                                                       3132 SN Cm
# type                                                                               RNA
#
# [38 rows x 93 columns]

# %%
print (gse.phenotype_data[["title", "source_name_ch1" , "characteristics_ch1.0.disease state"]])
# Out:
#                  title                          source_name_ch1  \
# GSM506037  1206 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506039  1364 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506040  1401 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506041  1516 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506042  1647 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506043  2515 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506044  2525 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506045  2685 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506046  2729 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506047  2829 BA9 Cf       Postmortem brain prefrontal cortex
# GSM506048  2977 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506050  3216 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506051  3236 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506052  3276 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506053  3397 BA9 Cf       Postmortem brain prefrontal cortex
# GSM506054  3401 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506055  3406 BA9 Cf       Postmortem brain prefrontal cortex
# GSM506056  3543 BA9 Cf       Postmortem brain prefrontal cortex
# GSM506057  3688 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506059  5138 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506060  5220 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506061  5398 BA9 Cf       Postmortem brain prefrontal cortex
# GSM506062  5441 BA9 Pf       Postmortem brain prefrontal cortex
# GSM506063  5476 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506064  5498 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506065   T55 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506066   T72 BA9 Pm       Postmortem brain prefrontal cortex
# GSM506067   T98 BA9 Cm       Postmortem brain prefrontal cortex
# GSM506068  T127 BA9 Pm       Postmortem brain prefrontal cortex
# GSM508594   1206 PT Cm                 Postmortem brain putamen
# ...                ...                                      ...
# GSM508713   2515 SN Pf  Postmortem brain whole substantia nigra
# GSM508714   2525 SN Pf  Postmortem brain whole substantia nigra
# GSM508715   2685 SN Pm  Postmortem brain whole substantia nigra
# GSM508716   2729 SN Pm  Postmortem brain whole substantia nigra
# GSM508717   2829 SN Cf  Postmortem brain whole substantia nigra
# GSM508718   2977 SN Pm  Postmortem brain whole substantia nigra
# GSM508720   3216 SN Cm  Postmortem brain whole substantia nigra
# GSM508721   3236 SN Cm  Postmortem brain whole substantia nigra
# GSM508722   3276 SN Cm  Postmortem brain whole substantia nigra
# GSM508723   3397 SN Cf  Postmortem brain whole substantia nigra
# GSM508724   3401 SN Cm  Postmortem brain whole substantia nigra
# GSM508725   3406 SN Cf  Postmortem brain whole substantia nigra
# GSM508726   3543 SN Cf  Postmortem brain whole substantia nigra
# GSM508728   5138 SN Pm  Postmortem brain whole substantia nigra
# GSM508729   5220 SN Cm  Postmortem brain whole substantia nigra
# GSM508730   5398 SN Cf  Postmortem brain whole substantia nigra
# GSM508731   5441 SN Pf  Postmortem brain whole substantia nigra
# GSM508732   5476 SN Pm  Postmortem brain whole substantia nigra
# GSM508733   5498 SN Cm  Postmortem brain whole substantia nigra
# GSM508734    T55 SN Cm  Postmortem brain whole substantia nigra
# GSM508735    T98 SN Cm  Postmortem brain whole substantia nigra
# GSM521253   3576 SN Cm  Postmortem brain whole substantia nigra
# GSM606619   1134 PT Cm                 Postmortem brain putamen
# GSM606620   1266 PT Cm                 Postmortem brain putamen
# GSM606621   3132 PT Cm                 Postmortem brain putamen
# GSM606622   3747 PT Cm                 Postmortem brain putamen
# GSM606623   5386 PT Cm                 Postmortem brain putamen
# GSM606624   1134 SN Cm  Postmortem brain whole substantia nigra
# GSM606625   1266 SN Cm  Postmortem brain whole substantia nigra
# GSM606626   3132 SN Cm  Postmortem brain whole substantia nigra
#
#           characteristics_ch1.0.disease state
# GSM506037                             control
# GSM506039                 Parkinson's disease
# GSM506040                 Parkinson's disease
# GSM506041                 Parkinson's disease
# GSM506042                 Parkinson's disease
# GSM506043                 Parkinson's disease
# GSM506044                 Parkinson's disease
# GSM506045                 Parkinson's disease
# GSM506046                 Parkinson's disease
# GSM506047                             control
# GSM506048                 Parkinson's disease
# GSM506050                             control
# GSM506051                             control
# GSM506052                             control
# GSM506053                             control
# GSM506054                             control
# GSM506055                             control
# GSM506056                             control
# GSM506057                             control
# GSM506059                 Parkinson's disease
# GSM506060                             control
# GSM506061                             control
# GSM506062                 Parkinson's disease
# GSM506063                 Parkinson's disease
# GSM506064                             control
# GSM506065                             control
# GSM506066                 Parkinson's disease
# GSM506067                             control
# GSM506068                 Parkinson's disease
# GSM508594                             Control
# ...                                       ...
# GSM508713                  Parkinsons disease
# GSM508714                  Parkinsons disease
# GSM508715                  Parkinsons disease
# GSM508716                  Parkinsons disease
# GSM508717                             Control
# GSM508718                  Parkinsons disease
# GSM508720                             Control
# GSM508721                             Control
# GSM508722                             Control
# GSM508723                             Control
# GSM508724                             Control
# GSM508725                             Control
# GSM508726                             Control
# GSM508728                  Parkinsons disease
# GSM508729                             Control
# GSM508730                             Control
# GSM508731                  Parkinsons disease
# GSM508732                  Parkinsons disease
# GSM508733                             Control
# GSM508734                             Control
# GSM508735                             Control
# GSM521253                             Control
# GSM606619                             Control
# GSM606620                             Control
# GSM606621                             Control
# GSM606622                             Control
# GSM606623                             Control
# GSM606624                             Control
# GSM606625                             Control
# GSM606626                             Control
#
# [93 rows x 3 columns]

# %%
experiments = {}
for i, (idx, row) in enumerate(gse.phenotype_data.iterrows()):
    tmp = {}
    tmp["Experiment"] = idx
    tmp["Type"] = row["characteristics_ch1.0.disease state"] 
    experiments[i] = tmp
experiments = pd.DataFrame(experiments).T
print (experiments)
# Out:
#    Experiment                 Type
# 0   GSM506037              control
# 1   GSM506039  Parkinson's disease
# 2   GSM506040  Parkinson's disease
# 3   GSM506041  Parkinson's disease
# 4   GSM506042  Parkinson's disease
# 5   GSM506043  Parkinson's disease
# 6   GSM506044  Parkinson's disease
# 7   GSM506045  Parkinson's disease
# 8   GSM506046  Parkinson's disease
# 9   GSM506047              control
# 10  GSM506048  Parkinson's disease
# 11  GSM506050              control
# 12  GSM506051              control
# 13  GSM506052              control
# 14  GSM506053              control
# 15  GSM506054              control
# 16  GSM506055              control
# 17  GSM506056              control
# 18  GSM506057              control
# 19  GSM506059  Parkinson's disease
# 20  GSM506060              control
# 21  GSM506061              control
# 22  GSM506062  Parkinson's disease
# 23  GSM506063  Parkinson's disease
# 24  GSM506064              control
# 25  GSM506065              control
# 26  GSM506066  Parkinson's disease
# 27  GSM506067              control
# 28  GSM506068  Parkinson's disease
# 29  GSM508594              Control
# ..        ...                  ...
# 63  GSM508713   Parkinsons disease
# 64  GSM508714   Parkinsons disease
# 65  GSM508715   Parkinsons disease
# 66  GSM508716   Parkinsons disease
# 67  GSM508717              Control
# 68  GSM508718   Parkinsons disease
# 69  GSM508720              Control
# 70  GSM508721              Control
# 71  GSM508722              Control
# 72  GSM508723              Control
# 73  GSM508724              Control
# 74  GSM508725              Control
# 75  GSM508726              Control
# 76  GSM508728   Parkinsons disease
# 77  GSM508729              Control
# 78  GSM508730              Control
# 79  GSM508731   Parkinsons disease
# 80  GSM508732   Parkinsons disease
# 81  GSM508733              Control
# 82  GSM508734              Control
# 83  GSM508735              Control
# 84  GSM521253              Control
# 85  GSM606619              Control
# 86  GSM606620              Control
# 87  GSM606621              Control
# 88  GSM606622              Control
# 89  GSM606623              Control
# 90  GSM606624              Control
# 91  GSM606625              Control
# 92  GSM606626              Control
#
# [93 rows x 2 columns]

# %%
experiments.Type == "Parkinson's disease"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22     True
# 23     True
# 24    False
# 25    False
# 26     True
# 27    False
# 28     True
# 29    False
#       ...
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Name: Type, Length: 93, dtype: bool

# %%
for time, group in experiments.groupby("Type"):
    print(time)
    transfection_name = group[group.Type == 'Parkinsons disease']
# Out:
# Control
# Parkinson's disease
# Parkinsons disease
# control

# %%
for i, a in experiments.groupby(['Type']):
    print(i)
    if i == 'Control' :
        transfection_name1 = a
    if i == 'control' :
        transfection_name2 = a
transfection_name = pd.concat([transfection_name2,transfection_name1])
# Out:
# Control
# Parkinson's disease
# Parkinsons disease
# control

# %%
transfection_name
# Out:
#    Experiment     Type
# 0   GSM506037  control
# 9   GSM506047  control
# 11  GSM506050  control
# 12  GSM506051  control
# 13  GSM506052  control
# 14  GSM506053  control
# 15  GSM506054  control
# 16  GSM506055  control
# 17  GSM506056  control
# 18  GSM506057  control
# 20  GSM506060  control
# 21  GSM506061  control
# 24  GSM506064  control
# 25  GSM506065  control
# 27  GSM506067  control
# 29  GSM508594  Control
# 38  GSM508683  Control
# 40  GSM508686  Control
# 41  GSM508687  Control
# 42  GSM508688  Control
# 43  GSM508689  Control
# 44  GSM508690  Control
# 45  GSM508691  Control
# 46  GSM508692  Control
# 47  GSM508693  Control
# 49  GSM508696  Control
# 51  GSM508699  Control
# 54  GSM508702  Control
# 55  GSM508703  Control
# 57  GSM508705  Control
# 59  GSM508708  Control
# 67  GSM508717  Control
# 69  GSM508720  Control
# 70  GSM508721  Control
# 71  GSM508722  Control
# 72  GSM508723  Control
# 73  GSM508724  Control
# 74  GSM508725  Control
# 75  GSM508726  Control
# 77  GSM508729  Control
# 78  GSM508730  Control
# 81  GSM508733  Control
# 82  GSM508734  Control
# 83  GSM508735  Control
# 84  GSM521253  Control
# 85  GSM606619  Control
# 86  GSM606620  Control
# 87  GSM606621  Control
# 88  GSM606622  Control
# 89  GSM606623  Control
# 90  GSM606624  Control
# 91  GSM606625  Control
# 92  GSM606626  Control

# %%
PD_sample = samples[transfection_name.Experiment]

# %%
PD_sample.head()
# Out:
# name       GSM506037  GSM506047  GSM506050  GSM506051  GSM506052  GSM506053  \
# ID_REF
# 1007_s_at  10.912450  11.629370  10.848290  11.058780  10.500090  11.017140
# 117_at      7.197164   7.175694   7.099503   7.518290   7.253250   7.349537
# 121_at      9.234383   9.245938   9.255750   9.357765   9.402947   9.217499
# 1294_at     7.596421   7.758112   7.574494   7.915527   7.626778   8.079367
# 1316_at     7.095303   6.946249   6.994520   7.507640   6.940020   7.411917
#
# name       GSM506054  GSM506055  GSM506056  GSM506057    ...      GSM508735  \
# ID_REF                                                   ...
# 1007_s_at  10.778150  10.855960  10.854620  10.196620    ...      12.018050
# 117_at      7.179747   7.118811   7.404522   7.300797    ...       7.050250
# 121_at      9.293650   9.074868   9.209644   9.156249    ...       9.236322
# 1294_at     7.907808   8.091028   7.847827   7.570650    ...       8.026506
# 1316_at     6.916110   6.997287   7.240456   6.843049    ...       6.232637
#
# name       GSM521253  GSM606619  GSM606620  GSM606621  GSM606622  GSM606623  \
# ID_REF
# 1007_s_at  11.639670   2248.440   2143.520   2171.840   3775.640   1423.300
# 117_at      7.119349    152.827    148.490    129.935    184.308    423.716
# 121_at      9.445329    759.988    935.717   1379.190   1253.160    755.072
# 1294_at     7.977628    264.273    237.344    246.465    252.270    244.816
# 1316_at     6.335979    146.966    239.745    299.628    231.731    208.184
#
# name       GSM606624  GSM606625  GSM606626
# ID_REF
# 1007_s_at   3190.330   2468.770   3616.590
# 117_at       189.210    176.259    155.537
# 121_at       800.507   1356.120   1649.250
# 1294_at      268.332    174.181    386.530
# 1316_at      145.039    159.895    205.464
#
# [5 rows x 53 columns]

# %%
PD_sample_annotated = PD_sample.reset_index().merge(gse.gpls['GPL96'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID", how='inner')

# %%
PD_sample_annotated.head()
# Out:
#       ID_REF  GSM506037  GSM506047  GSM506050  GSM506051  GSM506052  \
# 0  1007_s_at  10.912450  11.629370  10.848290  11.058780  10.500090
# 1     117_at   7.197164   7.175694   7.099503   7.518290   7.253250
# 2     121_at   9.234383   9.245938   9.255750   9.357765   9.402947
# 3    1294_at   7.596421   7.758112   7.574494   7.915527   7.626778
# 4    1316_at   7.095303   6.946249   6.994520   7.507640   6.940020
#
#    GSM506053  GSM506054  GSM506055  GSM506056         ...          GSM606619  \
# 0  11.017140  10.778150  10.855960  10.854620         ...           2248.440
# 1   7.349537   7.179747   7.118811   7.404522         ...            152.827
# 2   9.217499   9.293650   9.074868   9.209644         ...            759.988
# 3   8.079367   7.907808   8.091028   7.847827         ...            264.273
# 4   7.411917   6.916110   6.997287   7.240456         ...            146.966
#
#    GSM606620  GSM606621  GSM606622  GSM606623  GSM606624  GSM606625  \
# 0   2143.520   2171.840   3775.640   1423.300   3190.330   2468.770
# 1    148.490    129.935    184.308    423.716    189.210    176.259
# 2    935.717   1379.190   1253.160    755.072    800.507   1356.120
# 3    237.344    246.465    252.270    244.816    268.332    174.181
# 4    239.745    299.628    231.731    208.184    145.039    159.895
#
#    GSM606626         ID      ENTREZ_GENE_ID
# 0   3616.590  1007_s_at   780 /// 100616237
# 1    155.537     117_at                3310
# 2   1649.250     121_at                7849
# 3    386.530    1294_at  7318 /// 100847079
# 4    205.464    1316_at                7067
#
# [5 rows x 56 columns]

# %%
PD_sample_annotated = PD_sample_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
PD_sample_annotated = PD_sample_annotated[~PD_sample_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
PD_sample_annotated = PD_sample_annotated.groupby("ENTREZ_GENE_ID").median()

# %%
PD_sample_annotated.head()
# Out:
#                 GSM506037  GSM506047  GSM506050  GSM506051  GSM506052  \
# ENTREZ_GENE_ID
# 10               6.902423   7.140865   6.618146   7.395369   6.999914
# 100              6.683260   6.798898   6.632286   6.679559   6.689438
# 1000             9.451504   9.338521   9.374980   9.334977   9.307656
# 10000           10.010380   9.540787   9.928148   9.577258   9.747978
# 10002            6.617738   6.724372   6.647982   7.021555   6.824776
#
#                 GSM506053  GSM506054  GSM506055  GSM506056  GSM506057  \
# ENTREZ_GENE_ID
# 10               6.919354   6.764265   6.788673   7.025110   6.550003
# 100              7.025035   6.835648   6.646744   6.790812   6.706791
# 1000             9.049787   8.879257   8.953981   8.856516   9.539483
# 10000            9.411697   9.709774   9.401367   9.138815   9.822729
# 10002            6.976186   6.879354   6.841062   6.983679   6.738423
#
#                    ...      GSM508735  GSM521253  GSM606619  GSM606620  \
# ENTREZ_GENE_ID     ...
# 10                 ...       6.400746   6.737272   110.6690    36.9595
# 100                ...       6.489880   6.662290   262.9430   266.2854
# 1000               ...       8.026281   8.406145   548.2280   543.4455
# 10000              ...       8.831213   9.593173   678.3060  1553.2500
# 10002              ...       6.287621   6.720541    34.7071    14.2766
#
#                 GSM606621  GSM606622   GSM606623  GSM606624  GSM606625  \
# ENTREZ_GENE_ID
# 10                46.4748    44.1744    83.61170    78.2971    99.0373
# 100              278.0250   139.6480   215.96185   185.0850   240.6835
# 1000             591.8345   657.7995   508.96550   411.3955   360.2065
# 10000           1830.9900   875.1640  2269.72000  1125.5900  1351.2600
# 10002             45.6394    45.0064    15.35200    16.1787    38.9037
#
#                  GSM606626
# ENTREZ_GENE_ID
# 10                58.16140
# 100               94.88495
# 1000             358.23250
# 10000           1326.21000
# 10002             32.90280
#
# [5 rows x 53 columns]

# %%
PD_sample_annotated.tail()
# Out:
#                 GSM506037  GSM506047  GSM506050  GSM506051  GSM506052  \
# ENTREZ_GENE_ID
# 9989             7.887444   8.434657   8.397991   8.073536   7.940065
# 9990             6.396773   6.218091   6.083903   6.445069   6.328353
# 9992             7.816971   7.862365   7.728449   7.922197   7.710203
# 9993             8.437968   8.450620   8.494776   8.247144   8.425354
# 9997             7.216674   7.141466   7.254685   7.376620   7.192012
#
#                 GSM506053  GSM506054  GSM506055  GSM506056  GSM506057  \
# ENTREZ_GENE_ID
# 9989             8.384759   8.787691   8.412971   8.134871   7.767342
# 9990             6.137336   5.970027   6.208996   6.287614   6.328619
# 9992             7.819043   7.758790   8.027575   7.966858   7.514091
# 9993             8.644513   8.833695   8.825446   8.575159   8.511518
# 9997             7.344451   7.728693   7.465569   7.785880   8.000378
#
#                   ...      GSM508735  GSM521253  GSM606619  GSM606620  \
# ENTREZ_GENE_ID    ...
# 9989              ...       9.444531  10.458560   520.6670  1261.9900
# 9990              ...       5.994254   6.043085   282.9650   272.9300
# 9992              ...       7.891553   8.178162    44.9031    49.2851
# 9993              ...       8.132690   8.451035   360.5410  1435.8060
# 9997              ...       8.282561   7.757559   397.5710   139.7170
#
#                 GSM606621  GSM606622  GSM606623  GSM606624  GSM606625  \
# ENTREZ_GENE_ID
# 9989            1453.7000   797.2430  1485.6900  930.52100   908.8590
# 9990             263.8570   606.2270   171.6840  143.69400   285.8570
# 9992              76.4935    50.9743    45.8499   27.26960    62.9850
# 9993            1235.7210   494.0770   669.9423  919.78135  1276.7888
# 9997             189.0840   428.2810    86.8201  369.46900   604.4890
#
#                 GSM606626
# ENTREZ_GENE_ID
# 9989            1284.7200
# 9990             435.3920
# 9992              60.4703
# 9993            1070.7790
# 9997             318.0580
#
# [5 rows x 53 columns]

# %%
PD_sample_annotated.shape
# Out:
# (10344, 53)

# %%
PD_sample_annotated.fillna(1, inplace=True)

# %%
PD_sample_annotated.to_csv('PD_data_GEO_control.csv')
